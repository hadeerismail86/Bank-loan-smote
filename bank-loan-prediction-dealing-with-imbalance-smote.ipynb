# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read Data

# %%
data_credit_train = pd.read_csv('../input/my-dataset/credit_train.csv')
data_credit_test = pd.read_csv('../input/my-dataset/credit_test.csv')

# %%
data_credit_train
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
data_credit_test
# Out:
#                                     Loan ID  \
# 0      f738779f-c726-40dc-92cf-689d73af533d
# 1      6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2      f7744d01-894b-49c3-8777-fc6431a2cff1
# 3      83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4      08f3789f-5714-4b10-929d-e1527ab5e5a3
# ...                                     ...
# 10348                                   NaN
# 10349                                   NaN
# 10350                                   NaN
# 10351                                   NaN
# 10352                                   NaN
#
#                                 Customer ID  Current Loan Amount        Term  \
# 0      ded0b3c3-6bf4-4091-8726-47039f2c1b90             611314.0  Short Term
# 1      1630e6e3-34e3-461a-8fda-09297d3140c8             266662.0  Short Term
# 2      2c60938b-ad2b-4702-804d-eeca43949c52             153494.0  Short Term
# 3      12116614-2f3c-4d16-ad34-d92883718806             176242.0  Short Term
# ...

# %%
dftrain=data_credit_train.copy()
dftest=data_credit_test.copy()

# %% [markdown]
# # Data Describe

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
dftrain.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.000000e+05  80846.000000   8.084600e+04  100000.000000
# mean          1.176045e+07   1076.456089   1.378277e+06   18472.412336
# std           3.178394e+07   1475.403791   1.081360e+06   12174.992609
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.796520e+05    705.000000   8.488440e+05   10214.162500
# 50%           3.122460e+05    724.000000   1.174162e+06   16220.300000
# 75%           5.249420e+05    741.000000   1.650663e+06   24012.057500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            100000.000000                  46859.000000
# mean                 18.199141                     34.901321
# std                   7.015324                     21.997829
# min                   3.600000                      0.000000
# ...

# %%
dftrain.hist(bins = 10 , figsize= (14,10))
plt.show()

# %%
sns.boxplot(x=dftrain['Annual Income'])
# Out:
# <AxesSubplot:xlabel='Annual Income'>

# %%
dftrain.shape
# Out:
# (100514, 19)

# %%
dftest.shape
# Out:
# (10353, 18)

# %% [markdown]
# # Data cleaning and data visualization

# %%
dftrain.isnull().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
dftest.isnull().sum()
# Out:
# Loan ID                          353
# Customer ID                      353
# Current Loan Amount              353
# Term                             353
# Credit Score                    2334
# Annual Income                   2334
# Years in current job             780
# Home Ownership                   353
# Purpose                          353
# Monthly Debt                     353
# Years of Credit History          353
# Months since last delinquent    5659
# Number of Open Accounts          353
# Number of Credit Problems        353
# Current Credit Balance           353
# Maximum Open Credit              353
# Bankruptcies                     375
# Tax Liens                        354
# dtype: int64

# %%
dftrain.duplicated().sum()
# Out:
# 10728

# %%
dftrain.drop_duplicates(inplace = True)
dftrain.shape
# Out:
# (89786, 19)

# %%
dftest.duplicated().sum()
# Out:
# 352

# %%
dftest.drop_duplicates(inplace = True)
dftest.shape
# Out:
# (10001, 18)

# %%
dftrain.isnull().sum()
# Out:
# Loan ID                             1
# Customer ID                         1
# Loan Status                         1
# Current Loan Amount                 1
# Term                                1
# Credit Score                    19155
# Annual Income                   19155
# Years in current job             3803
# Home Ownership                      1
# Purpose                             1
# Monthly Debt                        1
# Years of Credit History             1
# Months since last delinquent    48338
# Number of Open Accounts             1
# Number of Credit Problems           1
# Current Credit Balance              1
# Maximum Open Credit                 3
# Bankruptcies                      191
# Tax Liens                          10
# dtype: int64

# %%
dftest.isnull().sum()
# Out:
# Loan ID                            1
# Customer ID                        1
# Current Loan Amount                1
# Term                               1
# Credit Score                    1982
# Annual Income                   1982
# Years in current job             428
# Home Ownership                     1
# Purpose                            1
# Monthly Debt                       1
# Years of Credit History            1
# Months since last delinquent    5307
# Number of Open Accounts            1
# Number of Credit Problems          1
# Current Credit Balance             1
# Maximum Open Credit                1
# Bankruptcies                      23
# Tax Liens                          2
# dtype: int64

# %%
sns.heatmap( dftrain.isnull(),cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap( dftest.isnull(),cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (15,5))
sns.countplot(x= dftrain["Years in current job"], palette="Set2")
# Out:
# <AxesSubplot:xlabel='Years in current job', ylabel='count'>

# %%
fig = px.pie(dftrain, names='Home Ownership', title='Home Ownership',color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
plt.figure(figsize = (25,10))
sns.countplot(x= dftrain["Purpose"], palette="Set2")
# Out:
# <AxesSubplot:xlabel='Purpose', ylabel='count'>

# %%
dftrain['Home Ownership'].value_counts()
# Out:
# Home Mortgage    43548
# Rent             37855
# Own Home          8199
# HaveMortgage       183
# Name: Home Ownership, dtype: int64

# %%
c = ['#724949','#cfa691', '#120f0f', '#a06868']
plt.figure(figsize=(7,7))
plt.pie(x = dftrain['Term'].value_counts(),
        labels=['Short term','Long term'],autopct='%.2f%%',
        textprops={'fontsize': 12},explode=[0,0.09], colors = ['#724949','#DEDCBB'])
plt.title('Time Period of Taking Loan',fontdict={'fontsize':15});

# %%
plt.figure(figsize = (15,5))
sns.countplot(x= dftrain["Term"], palette="Set2")
# Out:
# <AxesSubplot:xlabel='Term', ylabel='count'>

# %%
plt.figure(figsize = (15,5))
sns.countplot(x= dftest["Term"], palette="Set2")
# Out:
# <AxesSubplot:xlabel='Term', ylabel='count'>

# %% [markdown]
# # Drop the columns with > 50% missing

# %%
dftrain.drop(columns = ["Months since last delinquent"], inplace = True)

# %%
dftest.drop(columns = ["Months since last delinquent"], inplace = True)

# %%
dftrain.isnull().sum()
# Out:
# Loan ID                          1
# Customer ID                      1
# Loan Status                      1
# Current Loan Amount              1
# Term                             1
# Credit Score                 19155
# Annual Income                19155
# Years in current job          3803
# Home Ownership                   1
# Purpose                          1
# Monthly Debt                     1
# Years of Credit History          1
# Number of Open Accounts          1
# Number of Credit Problems        1
# Current Credit Balance           1
# Maximum Open Credit              3
# Bankruptcies                   191
# Tax Liens                       10
# dtype: int64

# %%
dftrain.dropna(thresh = 13, inplace = True)
dftrain.isnull().sum()
# Out:
# Loan ID                          0
# Customer ID                      0
# Loan Status                      0
# Current Loan Amount              0
# Term                             0
# Credit Score                 19154
# Annual Income                19154
# Years in current job          3802
# Home Ownership                   0
# Purpose                          0
# Monthly Debt                     0
# Years of Credit History          0
# Number of Open Accounts          0
# Number of Credit Problems        0
# Current Credit Balance           0
# Maximum Open Credit              2
# Bankruptcies                   190
# Tax Liens                        9
# dtype: int64

# %%
dftrain['Years in current job'].value_counts()
# Out:
# 10+ years    27755
# 2 years       8254
# < 1 year      7365
# 3 years       7339
# 5 years       6136
# 1 year        5832
# 4 years       5511
# 6 years       5134
# 7 years       4989
# 8 years       4121
# 9 years       3547
# Name: Years in current job, dtype: int64

# %%
fill_list = dftrain['Years in current job'].dropna()
dftrain['Years in current job'] = dftrain['Years in current job'].fillna(pd.Series(np.random.choice(fill_list , size = len(dftrain.index))))

# %%
dftrain.isnull().sum()
# Out:
# Loan ID                          0
# Customer ID                      0
# Loan Status                      0
# Current Loan Amount              0
# Term                             0
# Credit Score                 19154
# Annual Income                19154
# Years in current job           352
# Home Ownership                   0
# Purpose                          0
# Monthly Debt                     0
# Years of Credit History          0
# Number of Open Accounts          0
# Number of Credit Problems        0
# Current Credit Balance           0
# Maximum Open Credit              2
# Bankruptcies                   190
# Tax Liens                        9
# dtype: int64

# %%
fill_list = dftrain['Credit Score'].dropna()
dftrain['Credit Score'] = dftrain['Credit Score'].fillna(pd.Series(np.random.choice(fill_list , size = len(dftrain.index))))

# %%
fill_list = dftrain['Annual Income'].dropna()
dftrain['Annual Income'] = dftrain['Annual Income'].fillna(pd.Series(np.random.choice(fill_list , size = len(dftrain.index))))

# %%
dftrain.isnull().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                 1921
# Annual Income                1921
# Years in current job          352
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             2
# Bankruptcies                  190
# Tax Liens                       9
# dtype: int64

# %%
dftrain['Bankruptcies'].fillna(dftrain['Bankruptcies'].mean(),inplace = True)

# %%
dftrain['Tax Liens'].fillna(dftrain['Tax Liens'].mean(),inplace = True)

# %%
plt.figure(figsize = (15,7))
sns.kdeplot(x = dftrain["Credit Score"])
# Out:
# <AxesSubplot:xlabel='Credit Score', ylabel='Density'>

# %%
dftrain['Credit Score'].fillna(dftrain['Credit Score'].median(),inplace = True)

# %%
plt.figure(figsize = (15,7))
sns.kdeplot(x = dftrain["Credit Score"])
# Out:
# <AxesSubplot:xlabel='Credit Score', ylabel='Density'>

# %%
plt.figure(figsize = (15,7))
sns.kdeplot(x = dftrain["Annual Income"])
# Out:
# <AxesSubplot:xlabel='Annual Income', ylabel='Density'>

# %%
dftrain['Annual Income'].fillna(dftrain['Annual Income'].median(),inplace = True)

# %%
plt.figure(figsize = (15,7))
sns.kdeplot(x = dftrain["Annual Income"])
# Out:
# <AxesSubplot:xlabel='Annual Income', ylabel='Density'>

# %%
dftrain.dropna(subset=['Years in current job'],inplace=True)

# %%
dftrain.dropna(subset=['Maximum Open Credit'],inplace=True)

# %%
dftrain.isnull().sum()
# Out:
# Loan ID                      0
# Customer ID                  0
# Loan Status                  0
# Current Loan Amount          0
# Term                         0
# Credit Score                 0
# Annual Income                0
# Years in current job         0
# Home Ownership               0
# Purpose                      0
# Monthly Debt                 0
# Years of Credit History      0
# Number of Open Accounts      0
# Number of Credit Problems    0
# Current Credit Balance       0
# Maximum Open Credit          0
# Bankruptcies                 0
# Tax Liens                    0
# dtype: int64

# %%
dftest.isnull().sum()
# Out:
# Loan ID                         1
# Customer ID                     1
# Current Loan Amount             1
# Term                            1
# Credit Score                 1982
# Annual Income                1982
# Years in current job          428
# Home Ownership                  1
# Purpose                         1
# Monthly Debt                    1
# Years of Credit History         1
# Number of Open Accounts         1
# Number of Credit Problems       1
# Current Credit Balance          1
# Maximum Open Credit             1
# Bankruptcies                   23
# Tax Liens                       2
# dtype: int64

# %%
dftest.duplicated().sum()
# Out:
# 0

# %%
fill_list = dftest['Credit Score'].dropna()
dftest['Credit Score'] = dftest['Credit Score'].fillna(pd.Series(np.random.choice(fill_list , size = len(dftrain.index))))

# %%
fill_list = dftest['Annual Income'].dropna()
dftest['Annual Income'] = dftest['Annual Income'].fillna(pd.Series(np.random.choice(fill_list , size = len(dftrain.index))))

# %%
fill_list = dftest['Years in current job'].dropna()
dftest['Years in current job'] = dftest['Years in current job'].fillna(pd.Series(np.random.choice(fill_list , size = len(dftrain.index))))

# %%
dftest['Bankruptcies'].fillna(dftest['Bankruptcies'].mean(),inplace = True)

# %%
dftest.isnull().sum()
# Out:
# Loan ID                      1
# Customer ID                  1
# Current Loan Amount          1
# Term                         1
# Credit Score                 0
# Annual Income                0
# Years in current job         0
# Home Ownership               1
# Purpose                      1
# Monthly Debt                 1
# Years of Credit History      1
# Number of Open Accounts      1
# Number of Credit Problems    1
# Current Credit Balance       1
# Maximum Open Credit          1
# Bankruptcies                 0
# Tax Liens                    2
# dtype: int64

# %%
dftest.dropna(subset=['Loan ID'],inplace=True)
dftest.dropna(subset=['Customer ID'],inplace=True)
dftest.dropna(subset=['Current Loan Amount'],inplace=True)
dftest.dropna(subset=['Term'],inplace=True)
dftest.dropna(subset=['Home Ownership'],inplace=True)
dftest.dropna(subset=['Purpose'],inplace=True)
dftest.dropna(subset=['Monthly Debt'],inplace=True)
dftest.dropna(subset=['Years of Credit History'],inplace=True)
dftest.dropna(subset=['Number of Open Accounts'],inplace=True)
dftest.dropna(subset=['Number of Credit Problems'],inplace=True)
dftest.dropna(subset=['Current Credit Balance'],inplace=True)
dftest.dropna(subset=['Maximum Open Credit'],inplace=True)
dftest.dropna(subset=['Tax Liens'],inplace=True)

# %%
dftest.isnull().sum()
# Out:
# Loan ID                      0
# Customer ID                  0
# Current Loan Amount          0
# Term                         0
# Credit Score                 0
# Annual Income                0
# Years in current job         0
# Home Ownership               0
# Purpose                      0
# Monthly Debt                 0
# Years of Credit History      0
# Number of Open Accounts      0
# Number of Credit Problems    0
# Current Credit Balance       0
# Maximum Open Credit          0
# Bankruptcies                 0
# Tax Liens                    0
# dtype: int64

# %% [markdown]
# # Encoding the object Dataset

# %%
dftrain.describe(include=object)
# Out:
#                                      Loan ID  \
# count                                  89431
# unique                                 81700
# top     4c803c71-64e3-419a-86b5-2825cac7044a
# freq                                       2
#
#                                  Customer ID Loan Status        Term  \
# count                                  89431       89431       89431
# unique                                 81700           2           2
# top     f3a03e00-20ed-4b31-9887-dadef56e264f  Fully Paid  Short Term
# freq                                       2       66922       65720
#
#        Years in current job Home Ownership             Purpose
# count                 89431          89431               89431
# unique                   11              4                  16
# top               10+ years  Home Mortgage  Debt Consolidation
# freq                  28878          43396               70579

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
cols = ['Loan ID', 'Customer ID', 'Loan Status','Term','Years in current job','Purpose','Home Ownership']

# %%
dftrain[cols] = dftrain[cols].apply(LabelEncoder().fit_transform)

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89431 entries, 0 to 99998
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan ID                    89431 non-null  int64
#  1   Customer ID                89431 non-null  int64
#  2   Loan Status                89431 non-null  int64
#  3   Current Loan Amount        89431 non-null  float64
#  4   Term                       89431 non-null  int64
#  5   Credit Score               89431 non-null  float64
#  6   Annual Income              89431 non-null  float64
#  7   Years in current job       89431 non-null  int64
#  8   Home Ownership             89431 non-null  int64
#  9   Purpose                    89431 non-null  int64
#  10  Monthly Debt               89431 non-null  float64
#  11  Years of Credit History    89431 non-null  float64
#  12  Number of Open Accounts    89431 non-null  float64
# ...

# %%
dftest.describe(include=object)
# Out:
#                                      Loan ID  \
# count                                   9999
# unique                                  9999
# top     f738779f-c726-40dc-92cf-689d73af533d
# freq                                       1
#
#                                  Customer ID        Term Years in current job  \
# count                                   9999        9999                 9999
# unique                                  9999           2                   11
# top     ded0b3c3-6bf4-4091-8726-47039f2c1b90  Short Term            10+ years
# freq                                       1        7294                 3227
#
#        Home Ownership             Purpose
# count            9999                9999
# unique              4                  16
# top     Home Mortgage  Debt Consolidation
# freq             4867                7877

# %%
cols = ['Loan ID', 'Customer ID', 'Term','Years in current job','Purpose','Home Ownership']

dftest[cols] = dftest[cols].apply(LabelEncoder().fit_transform)

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89431 entries, 0 to 99998
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan ID                    89431 non-null  int64
#  1   Customer ID                89431 non-null  int64
#  2   Loan Status                89431 non-null  int64
#  3   Current Loan Amount        89431 non-null  float64
#  4   Term                       89431 non-null  int64
#  5   Credit Score               89431 non-null  float64
#  6   Annual Income              89431 non-null  float64
#  7   Years in current job       89431 non-null  int64
#  8   Home Ownership             89431 non-null  int64
#  9   Purpose                    89431 non-null  int64
#  10  Monthly Debt               89431 non-null  float64
#  11  Years of Credit History    89431 non-null  float64
#  12  Number of Open Accounts    89431 non-null  float64
# ...

# %%
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9999 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan ID                    9999 non-null   int64
#  1   Customer ID                9999 non-null   int64
#  2   Current Loan Amount        9999 non-null   float64
#  3   Term                       9999 non-null   int64
#  4   Credit Score               9999 non-null   float64
#  5   Annual Income              9999 non-null   float64
#  6   Years in current job       9999 non-null   int64
#  7   Home Ownership             9999 non-null   int64
#  8   Purpose                    9999 non-null   int64
#  9   Monthly Debt               9999 non-null   float64
#  10  Years of Credit History    9999 non-null   float64
#  11  Number of Open Accounts    9999 non-null   float64
#  12  Number of Credit Problems  9999 non-null   float64
# ...

# %% [markdown]
# # Correlation Graph of the Bank Loan Dataset

# %%
plt.figure(figsize = (20,10))
sns.heatmap(dftrain.corr() , annot = True , cmap = "BuPu")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (20,10))
sns.heatmap(dftest.corr() , annot = True , cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x = dftrain.drop(['Loan Status'] , axis = 1).values
y= dftrain['Loan Status'].values

# %%
x_train ,x_test, y_train , y_test = train_test_split(x,y, test_size= 0.25 , random_state= 42)

# %% [markdown]
# # Dealing with the imbalance problem

# %%
dftrain['Loan Status'].value_counts()/dftrain.shape[0]
# Out:
# 1    0.748309
# 0    0.251691
# Name: Loan Status, dtype: float64

# %%
sns.countplot(x=dftrain["Loan Status"])
# Out:
# <AxesSubplot:xlabel='Loan Status', ylabel='count'>

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(x, y)

# %%
x_train ,x_test ,y_train ,y_test=train_test_split(X_res, y_res  ,test_size=0.25,random_state=42)

# %% [markdown]
# # Modeling

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators= 5 , max_depth= 3 , max_features=4)

# %%
rf.fit(x_train , y_train)
print (rf.score(x_train , y_train))
print (rf.score(x_test , y_test))
# Out:
# 0.7373957741848719
# 0.7358716117270853

# %% [markdown]
# # XGBClassifier

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(n_estimators= 5 , max_depth= 3 , max_features=4)

# %%
xgb.fit(x_train , y_train)
# Out:
# [01:06:08] WARNING: ../src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=3, max_features=4, max_leaves=0,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
# ...

# %%
print (xgb.score(x_train , y_train))
print (xgb.score(x_test , y_test))
# Out:
# 0.7404142135620573
# 0.7406532978691611
